# %% [markdown]
# <a href="https://colab.research.google.com/github/jabarcmun/RNN/blob/main/InflacionMX_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ref: https://www.banxico.org.mx/SieInternet/consultarDirectorioInternetAction.do?accion=consultarCuadro&idCuadro=CP151&sector=8&locale=es

# %%
import pandas as pd

df = pd.read_excel('/content/Consulta_20251121-012416257.xlsx')
df.head(20)
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                       Banco de México  \
# 0                                                 NaN
# 1             Índices de Precios al Consumidor y UDIS
# 2                                           Inflación
# 3                                                 NaN
# 4              Fecha de consulta: 21/11/2025 01:24:16
# 5                                                 NaN
# 6   Aviso importante: Algunas de las series que es...
# 7                                                 NaN
# 8                                              Título
# 9                                  Periodo disponible
# 10                                       Periodicidad
# 11                                              Cifra
# 12                                             Unidad
# 13                                               Base
# 14                                              Aviso
# 15                                Tipo de información
# 16                                              Fecha
# 17                                1969-01-01 00:00:00
# 18                                1969-02-01 00:00:00
# 19                                1969-03-01 00:00:00
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Índice Nacional de Precios al consumidor, Vari...
# 9                                 Ene 1969 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP30577
# 17                                                N/E
# 18                                               0.36
# 19                                                0.1
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Índice Nacional de Precios al consumidor, Vari...
# 9                                 Ene 1970 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP30579
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Índice Nacional de Precios al consumidor, vari...
# 9                                 Ene 1970 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP30578
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Inflación, Subyacente (nueva definición), Mensual
# 9                                 Feb 1982 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74660
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Inflación, Subyacente (nueva definición), Acum...
# 9                                 Ene 1983 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74661
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 6  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8     Inflación, Subyacente (nueva definición), Anual
# 9                                 Ene 1983 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74662
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 7  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Inflación, No subyacente (nueva definición), M...
# 9                                 Feb 1982 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74663
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 8  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Inflación, No subyacente (nueva definición), A...
# 9                                 Ene 1983 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74664
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
#
#                                            Unnamed: 9
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Inflación, No subyacente (nueva definición), A...
# 9                                 Ene 1983 - Oct 2025
# 10                                            Mensual
# 11                                        Porcentajes
# 12                                         Sin Unidad
# 13                                                NaN
# 14  Acorde con la Ley del Sistema Nacional de Info...
# 15                                            Índices
# 16                                            SP74665
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E

# %%
# Seleccionar la fila 8 como encabezado (índice 7)
new_header = df.iloc[8]
new_header
# Out:
# Banco de México                                               Título
# Unnamed: 1         Índice Nacional de Precios al consumidor, Vari...
# Unnamed: 2         Índice Nacional de Precios al consumidor, Vari...
# Unnamed: 3         Índice Nacional de Precios al consumidor, vari...
# Unnamed: 4         Inflación, Subyacente (nueva definición), Mensual
# Unnamed: 5         Inflación, Subyacente (nueva definición), Acum...
# Unnamed: 6           Inflación, Subyacente (nueva definición), Anual
# Unnamed: 7         Inflación, No subyacente (nueva definición), M...
# Unnamed: 8         Inflación, No subyacente (nueva definición), A...
# Unnamed: 9         Inflación, No subyacente (nueva definición), A...
# Name: 8, dtype: object

# %%
# Crear un nuevo DataFrame desde la fila 17 en adelante
df = df[17:]
df
# Out:
#          Banco de México Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 17   1969-01-01 00:00:00        N/E        N/E        N/E        N/E
# 18   1969-02-01 00:00:00       0.36        N/E        N/E        N/E
# 19   1969-03-01 00:00:00        0.1        N/E        N/E        N/E
# 20   1969-04-01 00:00:00       0.27        N/E        N/E        N/E
# 21   1969-05-01 00:00:00          0        N/E        N/E        N/E
# ..                   ...        ...        ...        ...        ...
# 684  2024-08-01 00:00:00       0.01       2.75       4.99       0.22
# 685  2024-09-01 00:00:00       0.05        2.8       4.58       0.28
# 686  2024-10-01 00:00:00       0.55       3.37       4.76       0.28
# 687  2024-11-01 00:00:00       0.44       3.82       4.55       0.05
# 688  2024-12-01 00:00:00       0.38       4.21       4.21       0.51
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 17         N/E        N/E        N/E        N/E        N/E
# 18         N/E        N/E        N/E        N/E        N/E
# 19         N/E        N/E        N/E        N/E        N/E
# 20         N/E        N/E        N/E        N/E        N/E
# 21         N/E        N/E        N/E        N/E        N/E
# ..         ...        ...        ...        ...        ...
# 684        2.5          4       -0.7       3.43       8.03
# 685       2.79       3.91      -0.72       2.69        6.5
# 686       3.08        3.8       1.46       4.18       7.68
# 687       3.13       3.58       1.73       5.98        7.6
# 688       3.65       3.65      -0.04       5.95       5.95
#
# [672 rows x 10 columns]

# %%
# Asignar el nuevo encabezado
df.columns = new_header
df.head()
# Out:
# 8                Título  \
# 17  1969-01-01 00:00:00
# 18  1969-02-01 00:00:00
# 19  1969-03-01 00:00:00
# 20  1969-04-01 00:00:00
# 21  1969-05-01 00:00:00
#
# 8  Índice Nacional de Precios al consumidor, Variación mensual  \
# 17                                                N/E
# 18                                               0.36
# 19                                                0.1
# 20                                               0.27
# 21                                                  0
#
# 8  Índice Nacional de Precios al consumidor, Variación acumulada  \
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E
#
# 8  Índice Nacional de Precios al consumidor, variación anual  \
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E
#
# 8  Inflación, Subyacente (nueva definición), Mensual  \
# 17                                               N/E
# 18                                               N/E
# 19                                               N/E
# 20                                               N/E
# 21                                               N/E
#
# 8  Inflación, Subyacente (nueva definición), Acumulada en el año  \
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E
#
# 8  Inflación, Subyacente (nueva definición), Anual  \
# 17                                             N/E
# 18                                             N/E
# 19                                             N/E
# 20                                             N/E
# 21                                             N/E
#
# 8  Inflación, No subyacente (nueva definición), Mensual  \
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E
#
# 8  Inflación, No subyacente (nueva definición), Acumulada en el año  \
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E
#
# 8  Inflación, No subyacente (nueva definición), Anual
# 17                                                N/E
# 18                                                N/E
# 19                                                N/E
# 20                                                N/E
# 21                                                N/E

# %%
# Reiniciar el índice para que comience desde 0 en el nuevo DataFrame
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# 8               Título  \
# 0  1969-01-01 00:00:00
# 1  1969-02-01 00:00:00
# 2  1969-03-01 00:00:00
# 3  1969-04-01 00:00:00
# 4  1969-05-01 00:00:00
#
# 8 Índice Nacional de Precios al consumidor, Variación mensual  \
# 0                                                N/E
# 1                                               0.36
# 2                                                0.1
# 3                                               0.27
# 4                                                  0
#
# 8 Índice Nacional de Precios al consumidor, Variación acumulada  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Índice Nacional de Precios al consumidor, variación anual  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, Subyacente (nueva definición), Mensual  \
# 0                                               N/E
# 1                                               N/E
# 2                                               N/E
# 3                                               N/E
# 4                                               N/E
#
# 8 Inflación, Subyacente (nueva definición), Acumulada en el año  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, Subyacente (nueva definición), Anual  \
# 0                                             N/E
# 1                                             N/E
# 2                                             N/E
# 3                                             N/E
# 4                                             N/E
#
# 8 Inflación, No subyacente (nueva definición), Mensual  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, No subyacente (nueva definición), Acumulada en el año  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, No subyacente (nueva definición), Anual
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E

# %%
# Convertir la columna 'fecha' a tipo datetime
df['Fecha'] = pd.to_datetime(df['Título'])
df.head()
# Out:
# 8               Título  \
# 0  1969-01-01 00:00:00
# 1  1969-02-01 00:00:00
# 2  1969-03-01 00:00:00
# 3  1969-04-01 00:00:00
# 4  1969-05-01 00:00:00
#
# 8 Índice Nacional de Precios al consumidor, Variación mensual  \
# 0                                                N/E
# 1                                               0.36
# 2                                                0.1
# 3                                               0.27
# 4                                                  0
#
# 8 Índice Nacional de Precios al consumidor, Variación acumulada  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Índice Nacional de Precios al consumidor, variación anual  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, Subyacente (nueva definición), Mensual  \
# 0                                               N/E
# 1                                               N/E
# 2                                               N/E
# 3                                               N/E
# 4                                               N/E
#
# 8 Inflación, Subyacente (nueva definición), Acumulada en el año  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, Subyacente (nueva definición), Anual  \
# 0                                             N/E
# 1                                             N/E
# 2                                             N/E
# 3                                             N/E
# 4                                             N/E
#
# 8 Inflación, No subyacente (nueva definición), Mensual  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, No subyacente (nueva definición), Acumulada en el año  \
# 0                                                N/E
# 1                                                N/E
# 2                                                N/E
# 3                                                N/E
# 4                                                N/E
#
# 8 Inflación, No subyacente (nueva definición), Anual      Fecha
# 0                                                N/E 1969-01-01
# 1                                                N/E 1969-02-01
# 2                                                N/E 1969-03-01
# 3                                                N/E 1969-04-01
# 4                                                N/E 1969-05-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 11 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Título                                                            672 non-null    object
#  1   Índice Nacional de Precios al consumidor, Variación mensual       672 non-null    object
#  2   Índice Nacional de Precios al consumidor, Variación acumulada     672 non-null    object
#  3   Índice Nacional de Precios al consumidor, variación anual         672 non-null    object
#  4   Inflación, Subyacente (nueva definición), Mensual                 672 non-null    object
#  5   Inflación, Subyacente (nueva definición), Acumulada en el año     672 non-null    object
#  6   Inflación, Subyacente (nueva definición), Anual                   672 non-null    object
#  7   Inflación, No subyacente (nueva definición), Mensual              672 non-null    object
#  8   Inflación, No subyacente (nueva definición), Acumulada en el año  672 non-null    object
#  9   Inflación, No subyacente (nueva definición), Anual                672 non-null    object
#  10  Fecha                                                             672 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(10)
# memory usage: 57.9+ KB

# %%
# Filtrar por el año 2023
_df = df[(df['Fecha'] >= '01-01-2014') & (df['Fecha'] <= '12-31-2024')]
_df.head()
# Out:
# 8                 Título  \
# 540  2014-01-01 00:00:00
# 541  2014-02-01 00:00:00
# 542  2014-03-01 00:00:00
# 543  2014-04-01 00:00:00
# 544  2014-05-01 00:00:00
#
# 8   Índice Nacional de Precios al consumidor, Variación mensual  \
# 540                                               0.89
# 541                                               0.25
# 542                                               0.27
# 543                                              -0.19
# 544                                              -0.32
#
# 8   Índice Nacional de Precios al consumidor, Variación acumulada  \
# 540                                               0.89
# 541                                               1.15
# 542                                               1.43
# 543                                               1.24
# 544                                               0.91
#
# 8   Índice Nacional de Precios al consumidor, variación anual  \
# 540                                               4.48
# 541                                               4.23
# 542                                               3.76
# 543                                                3.5
# 544                                               3.51
#
# 8   Inflación, Subyacente (nueva definición), Mensual  \
# 540                                              0.85
# 541                                              0.28
# 542                                              0.21
# 543                                              0.29
# 544                                              0.09
#
# 8   Inflación, Subyacente (nueva definición), Acumulada en el año  \
# 540                                               0.85
# 541                                               1.14
# 542                                               1.35
# 543                                               1.65
# 544                                               1.74
#
# 8   Inflación, Subyacente (nueva definición), Anual  \
# 540                                            3.21
# 541                                            2.98
# 542                                            2.89
# 543                                            3.11
# 544                                               3
#
# 8   Inflación, No subyacente (nueva definición), Mensual  \
# 540                                               1.02
# 541                                               0.17
# 542                                               0.46
# 543                                              -1.67
# 544                                              -1.64
#
# 8   Inflación, No subyacente (nueva definición), Acumulada en el año  \
# 540                                               1.02
# 541                                               1.19
# 542                                               1.65
# 543                                              -0.05
# 544                                              -1.69
#
# 8   Inflación, No subyacente (nueva definición), Anual      Fecha
# 540                                               8.58 2014-01-01
# 541                                               8.28 2014-02-01
# 542                                               6.54 2014-03-01
# 543                                               4.75 2014-04-01
# 544                                               5.19 2014-05-01

# %%
_df.tail()
# Out:
# 8                 Título  \
# 667  2024-08-01 00:00:00
# 668  2024-09-01 00:00:00
# 669  2024-10-01 00:00:00
# 670  2024-11-01 00:00:00
# 671  2024-12-01 00:00:00
#
# 8   Índice Nacional de Precios al consumidor, Variación mensual  \
# 667                                               0.01
# 668                                               0.05
# 669                                               0.55
# 670                                               0.44
# 671                                               0.38
#
# 8   Índice Nacional de Precios al consumidor, Variación acumulada  \
# 667                                               2.75
# 668                                                2.8
# 669                                               3.37
# 670                                               3.82
# 671                                               4.21
#
# 8   Índice Nacional de Precios al consumidor, variación anual  \
# 667                                               4.99
# 668                                               4.58
# 669                                               4.76
# 670                                               4.55
# 671                                               4.21
#
# 8   Inflación, Subyacente (nueva definición), Mensual  \
# 667                                              0.22
# 668                                              0.28
# 669                                              0.28
# 670                                              0.05
# 671                                              0.51
#
# 8   Inflación, Subyacente (nueva definición), Acumulada en el año  \
# 667                                                2.5
# 668                                               2.79
# 669                                               3.08
# 670                                               3.13
# 671                                               3.65
#
# 8   Inflación, Subyacente (nueva definición), Anual  \
# 667                                               4
# 668                                            3.91
# 669                                             3.8
# 670                                            3.58
# 671                                            3.65
#
# 8   Inflación, No subyacente (nueva definición), Mensual  \
# 667                                               -0.7
# 668                                              -0.72
# 669                                               1.46
# 670                                               1.73
# 671                                              -0.04
#
# 8   Inflación, No subyacente (nueva definición), Acumulada en el año  \
# 667                                               3.43
# 668                                               2.69
# 669                                               4.18
# 670                                               5.98
# 671                                               5.95
#
# 8   Inflación, No subyacente (nueva definición), Anual      Fecha
# 667                                               8.03 2024-08-01
# 668                                                6.5 2024-09-01
# 669                                               7.68 2024-10-01
# 670                                                7.6 2024-11-01
# 671                                               5.95 2024-12-01

# %%
import matplotlib.pyplot as plt

# dates = pd.to_datetime(_df["Fecha"]).apply(lambda x: x.strftime('%Y-%m-%d')).tolist()
dates = _df["Fecha"].tolist()

# Grafica el "Índice Nacional de Precios al consumidor, variación anual"
plt.figure(figsize=(16, 10))
plt.plot(dates,_df["Índice Nacional de Precios al consumidor, variación anual"], color='blue', label="Variación anual")
plt.title("Índice Nacional de Precios al Consumidor - variación anual")
plt.xlabel("Tiempo")
plt.ylabel("Variación anual")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
X = _df.drop(columns=["Índice Nacional de Precios al consumidor, variación anual", "Título", "Fecha"])
y = _df["Índice Nacional de Precios al consumidor, variación anual"].values

# %%
X.shape
# Out:
# (132, 8)

# %%
y.shape
# Out:
# (132,)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.reshape(-1, 1))

# %%
import numpy as np

window_size = 12
X_rnn = []
y_rnn = []
# Construye secuencias temporales
for i in range(window_size, len(X_scaled)):
    X_rnn.append(X_scaled[i - window_size:i])
    y_rnn.append(y_scaled[i])

X_rnn, y_rnn = np.array(X_rnn), np.array(y_rnn)

# %%
split = int(len(X) * 0.8)
X_train, y_train = X_rnn[:split], y_rnn[:split]
X_test, y_test = X_rnn[split:], y_rnn[split:]

# %%
X_train.shape
# Out:
# (105, 12, 8)

# %%
y_test.shape
# Out:
# (15, 1)

# %%
window_size
# Out:
# 12

# %%
X_train.shape[2]
# Out:
# 8

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SimpleRNN, GRU

model = Sequential([
  SimpleRNN(units=60, return_sequences=True, input_shape=(window_size, X_train.shape[2])),
  SimpleRNN(units=30, return_sequences=True),
  SimpleRNN(units=15, return_sequences=False),
  Dense(units=1)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.optimizers import Adam

# Compilar el modelo
learning_rate = 0.001
adam_optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=adam_optimizer, loss='mean_squared_error')

# %%
# Entrenar el modelo
model.fit(X_train, y_train, batch_size=1, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.1654 - val_loss: 0.0103
# Epoch 2/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0240 - val_loss: 0.0079
# Epoch 3/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0128 - val_loss: 0.0061
# Epoch 4/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0091 - val_loss: 0.0062
# Epoch 5/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0097 - val_loss: 0.0042
# Epoch 6/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 7/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0087 - val_loss: 0.0069
# Epoch 8/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0155 - val_loss: 0.0049
# Epoch 9/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 10/10
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0089 - val_loss: 0.0173

# %%
# Predice en el conjunto de prueba y desescala los datos
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_original = scaler.inverse_transform(y_test)

# Muestra algunas predicciones y valores reales
print("Predicciones:", predictions.flatten()[:5])
print("Valores reales:", y_test_original.flatten()[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# Predicciones: [3.8138366 3.9674182 3.6255653 3.576012  3.6321917]
# Valores reales: [4.26 4.32 4.66 4.88 4.4 ]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(y_test, predictions)
print(f"Error Absoluto Medio (MAE): {mae}")

# Calcula el MSE
mse = mean_squared_error(y_test, predictions)
print(f"Error Cuadrático Medio (MSE): {mse}")

# Calcula el RMSE
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

# Calcula el Coeficiente de Determinación (R²)
r2 = r2_score(y_test, predictions)
print(f"Coeficiente de Determinación (R²): {r2}")
# Out:
# Error Absoluto Medio (MAE): 3.5005567317200095
# Error Cuadrático Medio (MSE): 12.327033033456955
# Raíz del Error Cuadrático Medio (RMSE): 3.5109874727000885
# Coeficiente de Determinación (R²): -4637.818391614416

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Gráfica de los valores reales y las predicciones del conjunto de prueba
valid = _df[split:]
valid = valid.reset_index(drop=True)
valid['Predictions'] = np.nan
valid.loc[window_size:, 'Predictions'] = predictions

dates_valid = pd.to_datetime(valid['Fecha']).apply(lambda x: x.strftime('%Y-%m-%d')).tolist()

plt.figure(figsize=(16, 8))
plt.title('Modelo RNN para Predicción de la inflación')
plt.xlabel('Fecha')
plt.ylabel('Inflacion')
plt.plot(dates_valid, valid[["Índice Nacional de Precios al consumidor, variación anual", 'Predictions']])
plt.legend(['Valor Real', 'Predicciones'], loc='lower right')
plt.xticks(rotation=90)
plt.show()
